# %%
import os
import pickle
import torch
import pandas as pd

# %%
# pkl_dict = "../../dataset/Compound_Word_Transformer_Uncond/representations/uncond/remi/ailab17k_from-scratch_remi/dictionary.pkl"
# remi_dictionary = pickle.load(open(pkl_dict, "rb"))
# len(remi_dictionary[0])

# %%
path_data_root = "../REMI/ailab17k_from-scratch_remi"
path_dictionary = os.path.join(path_data_root, 'dictionary.pkl')
dictionary = pickle.load(open(path_dictionary, "rb"))
event_to_int_no_key = dictionary[0]
len(event_to_int_no_key)
# Out:
# 338

# %%
key_profiles = ['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#','A', 'A#', 'B','c','c#', 'd', 'd#', 'e', 'f', 'f#', 'g', 'g#', 'a', 'a#', 'b']

# %%
event_to_int_key = event_to_int_no_key

# %%
for idx, i in enumerate(key_profiles):
    event_to_int["Key_" + i] = 338 + idx

# %%
int_to_event = {j:i for i,j in event_to_int.items()}

# %%
key_dictionary = (event_to_int, int_to_event)

# %%
path_data_root = "../REMI/ailab17k_from-scratch_remi"
path_dictionary = os.path.join(path_data_root, 'dictionary_with_key.pkl')
pickle.dump(key_dictionary, open(path_dictionary, 'wb'))

# %% [markdown]
# # Make REMI_Representation

# %%
matlab_path = "../dataset/matlab_feature/"
remi_dir = "../REMI/ailab17k_from-scratch_remi/events"
fnames = os.listdir(remi_dir)

# %%
def _get_remi_to_int(fnames, use_key = True):
    for fname in fnames:
        remi_example = pickle.load(open(os.path.join(remi_dir, fname), "rb"))
        fname = fname.split(".")[0].split("_seg")[0]
        if use_key:
            matlab_features = pd.read_csv(os.path.join(matlab_path, fname + ".csv"))
            key_profile = {"name": "Key", "value": matlab_features['keyname'].item()}
            remi_example = [key_profile] + remi_example
            int_example = [event_to_int_key[str(i['name'])+"_"+str(i['value'])] for i in remi_example]
            torch.save(int_example, os.path.join("../dataset/remi_midi", fname + ".pt"))
        else:
            int_example = [event_to_int_no_key[str(i['name'])+"_"+str(i['value'])] for i in remi_example]
            torch.save(int_example, os.path.join("../dataset/remi_key_midi", fname + ".pt"))
    return remi_example

# %%
r = _get_remi_to_int(fnames)

# %%
r
# Out:
# [{'name': 'Key', 'value': 'a'},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'N_N'},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Tempo', 'value': 194},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 125},
#  {'name': 'Beat', 'value': 14},
#  {'name': 'Note_Pitch', 'value': 65},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Beat', 'value': 15},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 120},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'D_M'},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Note_Pitch', 'value': 62},
#  {'name': 'Note_Velocity', 'value': 44},
#  {'name': 'Note_Duration', 'value': 1800},
#  {'name': 'Note_Pitch', 'value': 50},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 125},
#  {'name': 'Note_Pitch', 'value': 56},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Note_Pitch', 'value': 81},
#  {'name': 'Note_Velocity', 'value': 44},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': 48},
#  {'name': 'Note_Duration', 'value': 1440},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'A#_M7'},
#  {'name': 'Tempo', 'value': 131},
#  {'name': 'Beat', 'value': 1},
#  {'name': 'Note_Pitch', 'value': 46},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 62},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 137},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'D_+'},
#  {'name': 'Tempo', 'value': 125},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 131},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 137},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Tempo', 'value': 128},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'A#_M'},
#  {'name': 'Tempo', 'value': 137},
#  {'name': 'Beat', 'value': 2},
#  {'name': 'Note_Pitch', 'value': 65},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Beat', 'value': 3},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 120},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Chord', 'value': 'F_M7'},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Note_Pitch', 'value': 41},
#  {'name': 'Note_Velocity', 'value': 46},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 60},
#  {'name': 'Note_Velocity', 'value': 42},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'F_M'},
#  {'name': 'Tempo', 'value': 128},
#  {'name': 'Note_Pitch', 'value': 81},
#  {'name': 'Note_Velocity', 'value': 60},
#  {'name': 'Note_Duration', 'value': 1560},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': 62},
#  {'name': 'Note_Duration', 'value': 1560},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 125},
#  {'name': 'Note_Pitch', 'value': 48},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1080},
#  {'name': 'Note_Pitch', 'value': 41},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1080},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'F_M7'},
#  {'name': 'Tempo', 'value': 128},
#  {'name': 'Note_Pitch', 'value': 67},
#  {'name': 'Note_Velocity', 'value': 58},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 125},
#  {'name': 'Beat', 'value': 5},
#  {'name': 'Note_Pitch', 'value': 45},
#  {'name': 'Note_Velocity', 'value': 48},
#  {'name': 'Note_Duration', 'value': 1080},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'A_M7'},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Beat', 'value': 14},
#  {'name': 'Note_Pitch', 'value': 33},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Note_Pitch', 'value': 52},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 45},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 56},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'A_M'},
#  {'name': 'Tempo', 'value': 125},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 131},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 131},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'A_m'},
#  {'name': 'Tempo', 'value': 125},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Beat', 'value': 15},
#  {'name': 'Note_Pitch', 'value': 65},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 120},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 120},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'D_M'},
#  {'name': 'Tempo', 'value': 125},
#  {'name': 'Note_Pitch', 'value': 62},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 50},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': 46},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1080},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 50},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Chord', 'value': 'D_sus2'},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Note_Pitch', 'value': 76},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 840},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1200},
#  {'name': 'Note_Pitch', 'value': 50},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'D_+'},
#  {'name': 'Note_Pitch', 'value': 46},
#  {'name': 'Note_Velocity', 'value': 42},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 74},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 110},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'A#_M'},
#  {'name': 'Tempo', 'value': 113},
#  {'name': 'Note_Pitch', 'value': 53},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 46},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Beat', 'value': 14},
#  {'name': 'Note_Pitch', 'value': 65},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Beat', 'value': 15},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 120},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'F_M7'},
#  {'name': 'Tempo', 'value': 125},
#  {'name': 'Note_Pitch', 'value': 60},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 41},
#  {'name': 'Note_Velocity', 'value': 44},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 113},
#  {'name': 'Note_Pitch', 'value': 81},
#  {'name': 'Note_Velocity', 'value': 56},
#  {'name': 'Note_Duration', 'value': 1200},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': 54},
#  {'name': 'Note_Duration', 'value': 1440},
#  {'name': 'Note_Pitch', 'value': 41},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1440},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'F_M'},
#  {'name': 'Tempo', 'value': 116},
#  {'name': 'Note_Pitch', 'value': 48},
#  {'name': 'Note_Velocity', 'value': 42},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 104},
#  {'name': 'Note_Pitch', 'value': 67},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 840},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'A_m7'},
#  {'name': 'Tempo', 'value': 104},
#  {'name': 'Note_Pitch', 'value': 76},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1200},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 45},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'A_m'},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Note_Pitch', 'value': 33},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Note_Pitch', 'value': 52},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 60},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1080},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 116},
#  {'name': 'Note_Pitch', 'value': 65},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 14},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'D_m'},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Note_Pitch', 'value': 62},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Note_Pitch', 'value': 50},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': 60},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'D_m7'},
#  {'name': 'Tempo', 'value': 113},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': 42},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 116},
#  {'name': 'Note_Pitch', 'value': 72},
#  {'name': 'Note_Velocity', 'value': 62},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Note_Pitch', 'value': 65},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1680},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 116},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'F_M'},
#  {'name': 'Tempo', 'value': 113},
#  {'name': 'Note_Pitch', 'value': 53},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 110},
#  {'name': 'Beat', 'value': 14},
#  {'name': 'Note_Pitch', 'value': 65},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 53},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Note_Pitch', 'value': 41},
#  {'name': 'Note_Velocity', 'value': 44},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 60},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 122},
#  {'name': 'Note_Pitch', 'value': 81},
#  {'name': 'Note_Velocity', 'value': 58},
#  {'name': 'Note_Duration', 'value': 1800},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': 60},
#  {'name': 'Note_Duration', 'value': 1440},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Note_Pitch', 'value': 48},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 36},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 110},
#  {'name': 'Note_Pitch', 'value': 29},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Note_Pitch', 'value': 67},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'A_m7'},
#  {'name': 'Tempo', 'value': 101},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1440},
#  {'name': 'Note_Pitch', 'value': 45},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 107},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'A_m'},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Note_Pitch', 'value': 32},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Note_Pitch', 'value': 60},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 9},
#  {'name': 'Note_Pitch', 'value': 52},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 116},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Tempo', 'value': 125},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 110},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Tempo', 'value': 122},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'G_m'},
#  {'name': 'Tempo', 'value': 113},
#  {'name': 'Note_Pitch', 'value': 43},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 70},
#  {'name': 'Note_Velocity', 'value': 46},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 116},
#  {'name': 'Note_Pitch', 'value': 50},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 43},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1440},
#  {'name': 'Note_Pitch', 'value': 67},
#  {'name': 'Note_Velocity', 'value': 52},
#  {'name': 'Note_Duration', 'value': 1440},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'G_m7'},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Note_Pitch', 'value': 70},
#  {'name': 'Note_Velocity', 'value': 64},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 58},
#  {'name': 'Note_Velocity', 'value': 44},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'D_m7'},
#  {'name': 'Note_Pitch', 'value': 41},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 29},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': 52},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 122},
#  {'name': 'Note_Pitch', 'value': 48},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1440},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'F_M'},
#  {'name': 'Tempo', 'value': 113},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 110},
#  {'name': 'Note_Pitch', 'value': 60},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'D_m7'},
#  {'name': 'Tempo', 'value': 110},
#  {'name': 'Note_Pitch', 'value': 65},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 38},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 122},
#  {'name': 'Note_Pitch', 'value': 45},
#  {'name': 'Note_Velocity', 'value': 48},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 33},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'D_m'},
#  {'name': 'Tempo', 'value': 125},
#  {'name': 'Note_Pitch', 'value': 50},
#  {'name': 'Note_Velocity', 'value': 44},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 45},
#  {'name': 'Note_Velocity', 'value': 46},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 38},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': 42},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 104},
#  {'name': 'Note_Pitch', 'value': 53},
#  {'name': 'Note_Velocity', 'value': 54},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'D#_M7'},
#  {'name': 'Tempo', 'value': 95},
#  {'name': 'Note_Pitch', 'value': 67},
#  {'name': 'Note_Velocity', 'value': 66},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 63},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 104},
#  {'name': 'Note_Pitch', 'value': 46},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 34},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'D#_M'},
#  {'name': 'Tempo', 'value': 95},
#  {'name': 'Note_Pitch', 'value': 58},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 55},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Bar', 'value': None},
#  {'name': 'EOS', 'value': None}]

# %%
[k] + r
# Out:
# [{'name': 'Key', 'value': 'a'},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'N_N'},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Tempo', 'value': 194},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 125},
#  {'name': 'Beat', 'value': 14},
#  {'name': 'Note_Pitch', 'value': 65},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Beat', 'value': 15},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 120},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'D_M'},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Note_Pitch', 'value': 62},
#  {'name': 'Note_Velocity', 'value': 44},
#  {'name': 'Note_Duration', 'value': 1800},
#  {'name': 'Note_Pitch', 'value': 50},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 125},
#  {'name': 'Note_Pitch', 'value': 56},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Note_Pitch', 'value': 81},
#  {'name': 'Note_Velocity', 'value': 44},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': 48},
#  {'name': 'Note_Duration', 'value': 1440},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'A#_M7'},
#  {'name': 'Tempo', 'value': 131},
#  {'name': 'Beat', 'value': 1},
#  {'name': 'Note_Pitch', 'value': 46},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 62},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 137},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'D_+'},
#  {'name': 'Tempo', 'value': 125},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 131},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 137},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Tempo', 'value': 128},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'A#_M'},
#  {'name': 'Tempo', 'value': 137},
#  {'name': 'Beat', 'value': 2},
#  {'name': 'Note_Pitch', 'value': 65},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Beat', 'value': 3},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 120},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Chord', 'value': 'F_M7'},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Note_Pitch', 'value': 41},
#  {'name': 'Note_Velocity', 'value': 46},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 60},
#  {'name': 'Note_Velocity', 'value': 42},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'F_M'},
#  {'name': 'Tempo', 'value': 128},
#  {'name': 'Note_Pitch', 'value': 81},
#  {'name': 'Note_Velocity', 'value': 60},
#  {'name': 'Note_Duration', 'value': 1560},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': 62},
#  {'name': 'Note_Duration', 'value': 1560},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 125},
#  {'name': 'Note_Pitch', 'value': 48},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1080},
#  {'name': 'Note_Pitch', 'value': 41},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1080},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'F_M7'},
#  {'name': 'Tempo', 'value': 128},
#  {'name': 'Note_Pitch', 'value': 67},
#  {'name': 'Note_Velocity', 'value': 58},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 125},
#  {'name': 'Beat', 'value': 5},
#  {'name': 'Note_Pitch', 'value': 45},
#  {'name': 'Note_Velocity', 'value': 48},
#  {'name': 'Note_Duration', 'value': 1080},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'A_M7'},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Beat', 'value': 14},
#  {'name': 'Note_Pitch', 'value': 33},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Note_Pitch', 'value': 52},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 45},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 56},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'A_M'},
#  {'name': 'Tempo', 'value': 125},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 131},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 131},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'A_m'},
#  {'name': 'Tempo', 'value': 125},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Beat', 'value': 15},
#  {'name': 'Note_Pitch', 'value': 65},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 120},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 120},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'D_M'},
#  {'name': 'Tempo', 'value': 125},
#  {'name': 'Note_Pitch', 'value': 62},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 50},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': 46},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1080},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 50},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Chord', 'value': 'D_sus2'},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Note_Pitch', 'value': 76},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 840},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1200},
#  {'name': 'Note_Pitch', 'value': 50},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'D_+'},
#  {'name': 'Note_Pitch', 'value': 46},
#  {'name': 'Note_Velocity', 'value': 42},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 74},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 110},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'A#_M'},
#  {'name': 'Tempo', 'value': 113},
#  {'name': 'Note_Pitch', 'value': 53},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 46},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Beat', 'value': 14},
#  {'name': 'Note_Pitch', 'value': 65},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Beat', 'value': 15},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 120},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'F_M7'},
#  {'name': 'Tempo', 'value': 125},
#  {'name': 'Note_Pitch', 'value': 60},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 41},
#  {'name': 'Note_Velocity', 'value': 44},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 113},
#  {'name': 'Note_Pitch', 'value': 81},
#  {'name': 'Note_Velocity', 'value': 56},
#  {'name': 'Note_Duration', 'value': 1200},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': 54},
#  {'name': 'Note_Duration', 'value': 1440},
#  {'name': 'Note_Pitch', 'value': 41},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1440},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'F_M'},
#  {'name': 'Tempo', 'value': 116},
#  {'name': 'Note_Pitch', 'value': 48},
#  {'name': 'Note_Velocity', 'value': 42},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 104},
#  {'name': 'Note_Pitch', 'value': 67},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 840},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'A_m7'},
#  {'name': 'Tempo', 'value': 104},
#  {'name': 'Note_Pitch', 'value': 76},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1200},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 45},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'A_m'},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Note_Pitch', 'value': 33},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Note_Pitch', 'value': 52},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 60},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1080},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 116},
#  {'name': 'Note_Pitch', 'value': 65},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 14},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'D_m'},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Note_Pitch', 'value': 62},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Note_Pitch', 'value': 50},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': 60},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'D_m7'},
#  {'name': 'Tempo', 'value': 113},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': 42},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 116},
#  {'name': 'Note_Pitch', 'value': 72},
#  {'name': 'Note_Velocity', 'value': 62},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Note_Pitch', 'value': 65},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1680},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 116},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'F_M'},
#  {'name': 'Tempo', 'value': 113},
#  {'name': 'Note_Pitch', 'value': 53},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 110},
#  {'name': 'Beat', 'value': 14},
#  {'name': 'Note_Pitch', 'value': 65},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 53},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Note_Pitch', 'value': 41},
#  {'name': 'Note_Velocity', 'value': 44},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 60},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 122},
#  {'name': 'Note_Pitch', 'value': 81},
#  {'name': 'Note_Velocity', 'value': 58},
#  {'name': 'Note_Duration', 'value': 1800},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': 60},
#  {'name': 'Note_Duration', 'value': 1440},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Note_Pitch', 'value': 48},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 36},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 110},
#  {'name': 'Note_Pitch', 'value': 29},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Note_Pitch', 'value': 67},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'A_m7'},
#  {'name': 'Tempo', 'value': 101},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1440},
#  {'name': 'Note_Pitch', 'value': 45},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 107},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'A_m'},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Note_Pitch', 'value': 32},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Note_Pitch', 'value': 60},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 9},
#  {'name': 'Note_Pitch', 'value': 52},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 116},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Tempo', 'value': 125},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 110},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Tempo', 'value': 122},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'G_m'},
#  {'name': 'Tempo', 'value': 113},
#  {'name': 'Note_Pitch', 'value': 43},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 70},
#  {'name': 'Note_Velocity', 'value': 46},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 116},
#  {'name': 'Note_Pitch', 'value': 50},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 43},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1440},
#  {'name': 'Note_Pitch', 'value': 67},
#  {'name': 'Note_Velocity', 'value': 52},
#  {'name': 'Note_Duration', 'value': 1440},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'G_m7'},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Note_Pitch', 'value': 70},
#  {'name': 'Note_Velocity', 'value': 64},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 58},
#  {'name': 'Note_Velocity', 'value': 44},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'D_m7'},
#  {'name': 'Note_Pitch', 'value': 41},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 29},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': 52},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 122},
#  {'name': 'Note_Pitch', 'value': 48},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1440},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'F_M'},
#  {'name': 'Tempo', 'value': 113},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 110},
#  {'name': 'Note_Pitch', 'value': 60},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'D_m7'},
#  {'name': 'Tempo', 'value': 110},
#  {'name': 'Note_Pitch', 'value': 65},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 38},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 122},
#  {'name': 'Note_Pitch', 'value': 45},
#  {'name': 'Note_Velocity', 'value': 48},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 33},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'D_m'},
#  {'name': 'Tempo', 'value': 125},
#  {'name': 'Note_Pitch', 'value': 50},
#  {'name': 'Note_Velocity', 'value': 44},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 45},
#  {'name': 'Note_Velocity', 'value': 46},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 38},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': 42},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': 104},
#  {'name': 'Note_Pitch', 'value': 53},
#  {'name': 'Note_Velocity', 'value': 54},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'D#_M7'},
#  {'name': 'Tempo', 'value': 95},
#  {'name': 'Note_Pitch', 'value': 67},
#  {'name': 'Note_Velocity', 'value': 66},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 63},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': 104},
#  {'name': 'Note_Pitch', 'value': 46},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 34},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'D#_M'},
#  {'name': 'Tempo', 'value': 95},
#  {'name': 'Note_Pitch', 'value': 58},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Note_Pitch', 'value': 55},
#  {'name': 'Note_Velocity', 'value': 40},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Bar', 'value': None},
#  {'name': 'EOS', 'value': None}]

# %%
remi_example[:5]
# Out:
# [{'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'N_N'},
#  {'name': 'Tempo', 'value': 119},
#  {'name': 'Beat', 'value': 8}]

# %%
# values : A	A#	B	C	C#	D	D#	...	b	c	c#	d	d#	e	f	f#	g	g#
{"name": "Key", "value": "A"}
# Out:
# 'Q3_xYZ8n8ULaNo_0.mid.pkl'

# %%
temp = torch.load(os.path.join("../dataset/magenta_midi", "Q3_xYZ8n8ULaNo_0.pt"))

# %%
import numpy as np
np.array(temp).max()
# Out:
# 372

# %% [markdown]
# # Data Split

# %%
index_list = []
fname_list = []
label_list = []
for i in fnames:
    index_name = i.split(".mid")[0].split("_seg")[0]
    f_name = "_".join(i.split(".mid")[0].split("_")[1:-1])
    label = i.split("_")[0]
    index_list.append(index_name)
    label_list.append(label)
    fname_list.append(f_name)

# %%
df = pd.DataFrame(label_list, index=index_list, columns=['label'])
df.head()
# Out:
#                  label
# Q3_xYZ8n8ULaNo_0    Q3
# Q2_48EYLEAgaBc_1    Q2
# Q4_j8Ir-ssM-AA_0    Q4
# Q4_I2MrA-o5H8I_2    Q4
# Q4_ltNK_MY1HkM_2    Q4

# %%
len(df)
# Out:
# 1052

# %%
from collections import Counter
from sklearn.model_selection import train_test_split

train_val, test = train_test_split(df, test_size=0.1, random_state=42, stratify=df['label'])
len(train_val) ,Counter(train_val['label']), len(test), Counter(test['label'])
# Out:
# (946,
#  Counter({'Q2': 236, 'Q3': 219, 'Q1': 215, 'Q4': 276}),
#  106,
#  Counter({'Q1': 24, 'Q4': 31, 'Q3': 25, 'Q2': 26}))

# %%
train, val = train_test_split(train_val, test_size=0.215, random_state=42, stratify=train_val['label'])
len(train) ,Counter(train['label']), len(val), Counter(val['label'])
# Out:
# (742,
#  Counter({'Q4': 216, 'Q1': 169, 'Q3': 172, 'Q2': 185}),
#  204,
#  Counter({'Q4': 60, 'Q1': 46, 'Q2': 51, 'Q3': 47}))

# %%
# train.to_csv("../dataset/split/train.csv")
# val.to_csv("../dataset/split/val.csv")
# test.to_csv("../dataset/split/test.csv")
